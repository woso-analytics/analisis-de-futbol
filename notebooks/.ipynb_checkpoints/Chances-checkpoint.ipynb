# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import matplotlib.image as mpimg
import matplotlib.patches as patches
import matplotlib as mpl
from mplsoccer import Pitch, VerticalPitch, FontManager, Sbopen, add_image
from matplotlib.font_manager import FontProperties
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.patheffects as path_effects
from highlight_text import ax_text, fig_text
from PIL import Image
from mplsoccer import add_image
from urllib.request import urlopen
import matplotlib.patches as mpatches
import glob
import urllib

# %%
# Print the modified DataFrame
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

green = '#69f900'
red = '#cb2217'
blue = '#00285e'
sky_blue = '#6caddf'
bg_color= '#fffcf7'
gold = '#ffc758'
line_color= '#000000'
# col1 = '#1C2C5B'
# col2 = '#6CABDD'

# %%
path = r'C:\Users\MIRIRAI\Documents\Joel\Analisis-de-fulbo-main\WSL24-25' # use your path
all_files = glob.glob(os.path.join(path, "*.csv"))

df = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)

# %%
df["receiver"] = df["name"].shift(-1)

# %%
fig = plt.figure(figsize=(10,10), dpi=300, facecolor='#F6F7F8')
ax = plt.subplot(111)
pitch = Pitch(
    pitch_type='uefa',
    goal_type='box',
    linewidth=.85,
    line_color='black',
    pitch_color='#F6F7F8'
)
pitch.draw(ax = ax)
plt.rcParams["font.family"] = "DM Sans"

bbox_pad = .8
bboxprops = {'linewidth': 0, 'pad': bbox_pad}

ax1 = fig.add_axes([0, 0.7, 1, .15])
ax1.set_facecolor('#ffffff')
ax1.set_xlim(0, 1)
ax1.set_ylim(0, 1)


ax1.text(
    x=0.5,
    y=.6,
    s=f'Mourning {pname}: Day 1',
    fontsize=20,
#     fontproperties=font_props,
    fontweight='bold',
    color='#00285e',
    ha='center'
)
fig_text(
    x = 0.5, y = .77, 
    s=f'{pname} has created <{df_passes.shape[0]} chances> and got <8 assists> from them',
    fontsize=10,
    highlight_textprops=[{'color': 'w', 'weight': 'bold', 'bbox': {'facecolor':'#1C2C5B', **bboxprops}},
                         {'color': 'w', 'weight': 'bold', 'bbox': {'facecolor':'#D4A12A', **bboxprops}},
                        ],
    color='#4E616C',
    ha='center',
    ax = ax1
)

fig_text(
    x = 0.8, y = .76,
    s = "| <Inside MCWFC>",
    highlight_textprops = [
        {"color":"#00285e", "weight": "bold"}
    ],
    color = '#ffc758',
    size = 10,
    annotationbbox_kw={"xycoords": "figure fraction"}
)

fig_text(
    x = 0.8, y = 0.24,
    s = "Viz by: @joellikesthis",
    color = "#00285e",
    size = 7,
    annotationbbox_kw={"xycoords": "figure fraction"}
)


ax1.set_axis_off()

ax1.set_axis_off()

for index, row in df_passes.iterrows():
    if 'GoalAssist' in row['qualifiers']:
        p_arrow = mpatches.FancyArrowPatch((row.x,row.y), (row.endX, row.endY), ec='#D4A12A',
                                                    fc='None',arrowstyle='-|>,head_length=3,head_width=2', zorder=1)
        ax.add_patch(p_arrow)
    else:
        p_arrow = mpatches.FancyArrowPatch((row.x,row.y), (row.endX, row.endY), ec='#1C2C5B',
                                                    fc='None',arrowstyle='-|>,head_length=3,head_width=2', zorder=1)
        ax.add_patch(p_arrow)



fotmob_url = 'https://images.fotmob.com/image_resources/logo/leaguelogo/9227.png'
club_icon = Image.open(urllib.request.urlopen(f'{fotmob_url}'))
ax_timage = add_image(club_icon, fig, left=0.85, bottom=0.79, width=0.040, height=0.040)

city_url = 'https://images.fotmob.com/image_resources/logo/teamlogo/231488.png'
club_icon = Image.open(urllib.request.urlopen(f'{city_url}'))
ax_timage = add_image(club_icon, fig, left=0.1, bottom=0.79, width=0.050, height=0.050)
